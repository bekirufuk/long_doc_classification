# %%
# %ls
# Out:
# class_manager.ipynb  pmi.py         process.py  tokenizer_trainer.py
# __init__.py          preprocess.py  tfidf.py    train_tokenizer.ipynb

# %%
import pandas as pd

# %%
df = pd.read_csv('../../data/refined_patents/chunks/patents_2020_chunk_000.csv')

# %%
df
# Out:
#     patent_id                                               text  labels  \
# 0    10617544  DESCRIPTION OF EMBODIMENTS\n\nSpecific embodim...       0
# 1    10619990  DETAILED DESCRIPTION OF THE INVENTION\n\nRefer...       0
# 2    10624688  BEST MODE\n\nHereinafter, embodiments of the p...       0
# 3    10618771  DETAILED DESCRIPTION OF THE PREFERRED EMBODIME...       0
# 4    10612166  DETAILED DESCRIPTION\n\nFor purposes of descri...       0
# ..        ...                                                ...     ...
# 411  10630250  DETAILED DESCRIPTION\n\nBefore the disclosure ...       7
# 412  10629722  DESCRIPTION OF EMBODIMENTS\n\nNext, embodiment...       7
# 413  10615668  DETAILED DESCRIPTION\n\nIt is understood that ...       7
# 414  10629344  It is noted that the drawings may not be to sc...       7
# 415  10629486  DETAILED DESCRIPTION\n\nElements that are iden...       7
#
#      ipc_class subclass  word_counts
# 0           61        F         3371
# ...
